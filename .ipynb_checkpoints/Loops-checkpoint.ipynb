# %% [markdown]
# # Loops

# %%
fruits=["Banana", "Mango","Apple"]
for x in fruits:
 print(x)
# Out:
# Banana
# Mango
# Apple

# %%
fruits=["Banana", "Mango", "Apple"]
for x in fruits:
 print(x)
 if x == "Banana":
  break
# Out:
# Banana

# %%
fruits=["Mango", "Banana", "Apple"]
for x in fruits:
 print(x)
 if x== "Banana":
  continue
# Out:
# Mango
# Banana
# Apple
